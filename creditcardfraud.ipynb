# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import scipy.stats as stats
import plotly.express as px
import plotly.graph_objects as go
from pylab import rcParams

# %%
data1 = pd.read_csv(r"C:\Users\ASUS\Documents\datasets for visulaization\creditcard.csv")
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data1.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data1.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data1.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data1.shape
# Out:
# (284807, 31)

# %%
amount = data1['Amount'].value_counts()
amount
# Out:
# Amount
# 1.00       13688
# 1.98        6044
# 0.89        4872
# 9.99        4747
# 15.00       3280
#            ...
# 62.09          1
# 552.05         1
# 1467.75        1
# 196.68         1
# 95.63          1
# Name: count, Length: 32767, dtype: int64

# %%
data1.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#SPLIT THE DATA BASED ON CLASS - FRAUD AND NORMAL
fraud = data1[data1.Class==1]
normal = data1[data1.Class==0]
print(f"fraud : {fraud.shape}")
print(f"normal : {normal.shape}")
# Out:
# fraud : (492, 31)
# normal : (284315, 31)

# %%
#GETTING THE TOTAL FRAUD TRANSACTION AND NORMAL TRANSACTION
print("fraud transaction = ",len(fraud))
print("normal transaction = ",len(normal))
# Out:
# fraud transaction =  492
# normal transaction =  284315

# %%
#FROM HERE THE VISUALIZATION IS STARTED
#BARGRAPH FOR BOTH CLASS 1 AND 0
class_count = pd.value_counts(data1['Class'], sort = True)
class_count.plot(kind = 'bar', rot = 0, figsize = (8 , 6), title = 'Class Distribution')
plt.xticks(range(2), ['normal','fraud'])
plt.ylabel("count")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4992\941839095.py:3: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %%
#PLOT THE CLASS DISTRIBUTION
fig = go.Figure(data =[go.Pie(labels=['normal','fraud'], values = [len(normal), len(fraud)])])
fig.show()

# %%
#EXTRACTING THE 1 WHICH IS NORMAL TRANSACTION 
normal.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#SAME FOR FRAUD TRANSACTION 
fraud.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#GETTING THE TOTAL AMOUNT FOR BOTH NORMAL AND FRAUD
print('normal = ', normal.Amount.describe())
print('fraud = ', fraud.Amount.describe())
# Out:
# normal =  count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64
# fraud =  count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#FROM PLOTTING WE CAN SEE THE DISTRIBUTION OF AMOUNT FOR FRAUD AND NORMAL TRANSACTIONS

def plot_hist(data1, bins,column,log_scale = True):
    bins = 100
    fraud = data1[data1.Class == 1]
    normal = data1[data1.Class == 0]
    fig,(ax1,ax2) = plt.subplots(2,1,sharex = True, figsize=(6,4))
    fig.suptitle(f"counts of {column} transaction")
    
    ax1.hist(fraud[column], bins = bins, color = 'r', alpha =0.5, density = True)
    ax1.set_title('fraud')
    
    ax2.hist(normal[column],bins=bins, color = 'g', alpha = 0.5, density = True)
    ax2.set_title('normal')

    
    plt.xlabel(column)
    plt.ylabel("counts")

    
    if log_scale:
        plt.yscale('log')

    plt.xlim((np.min(data1[column]), np.max(data1[column])))
    plt.show()

# %%
bins = 100
plot_hist(data1, bins, 'Amount')

# %%
#THIS SHOWS THAT THE FRAUD TRANSACTIONS DONT HAVE HIGH VALUES AT ALL
#LET UNDERSTAND BY ANOTHER VISUALIZATION BY BOXPLOTTING
fig, (ax1,ax2) = plt.subplots(2,1, figsize = (6,4), sharex = True)
fig.suptitle('Boxplot of transaction Amount')

ax1.boxplot(fraud.Amount, vert = False, labels = ['fraud'])
ax1.set_title('fraud')

ax2.boxplot(normal.Amount, vert = False, labels = ['normal'])
ax2.set_title('normal')
# Out:
# Text(0.5, 1.0, 'normal')

# %%
#THERE ARE OUTLIERS WITH HEAVEY AMOUNT IN NORMAL DATASET
fraud_outliers = fraud[fraud.Amount > 10000]
normal_outliers = normal[normal.Amount > 2500]

print(f"Fraud outliers : {fraud_outliers.shape}")
print(f"Normal outliers : {normal_outliers.shape}")
# Out:
# Fraud outliers : (0, 31)
# Normal outliers : (440, 31)

# %%
#COMPARISON BETWEEN FRAUD AMOUNT AND NORMAL AMOUNT
fig,(ax1,ax2) = plt.subplots(2,1, figsize = (6,4), sharex = True)
fig.suptitle('Transaction Amount Comparison')

ax1.scatter(fraud.index, fraud.Amount, color = 'r', alpha = 0.5)
ax1.set_title('Fraud')

ax2.scatter(normal.index, normal.Amount, color = 'y', alpha = 0.5)
ax2.set_title('Normal')

plt.xlabel('Transaction index')
# Out:
# Text(0.5, 0, 'Transaction index')

# %%
fig,ax = plt.subplots(1,2, figsize = (15,6))
fig.suptitle('Comparison between fraud and normal transaction wrt amount')

sns.kdeplot(normal["Amount"], label = "Amount", ax = ax[0])

sns.kdeplot(fraud["Amount"], label = "Amount", ax = ax[1])


plt.show()

# %%
#FOR LOW AMOUNT OF TRANSACTION , THE PROBABILITY OF FRAUD IS MORE THAN A REGULAR TRANSACTION, BUT MOST OF THE TRANSACTION ARE NORMAL

fig,ax = plt.subplots(9,3, figsize = (40,40))
ax = ax.flatten()

for i,column in enumerate(data1.columns[1:28]):
    sns.boxplot(x = 'Class', y = column, data = data1, ax = ax[i])

    plt.xlabel('Class')
    plt.ylabel(column)
    plt.tight_layout()

    fig.suptitle('Fraud Vs Normal Transactions wrt Features')

# %%
fig,ax = plt.subplots(9,3, figsize = (40,40))
ax = ax.flatten()

for i,column in enumerate(data1.columns[1:28]):
    sns.histplot(data = data1, x = data1[column], ax = ax[i])

    plt.xlabel(column)
    plt.ylabel('Density')
    plt.tight_layout()

plt.show()

# %%
#FEATURE BY CORRELATION

plt.figure(figsize=(30,20))
sns.heatmap(data1.corr(), cbar = True, annot = True, cmap = 'coolwarm', fmt = '.2f')
# Out:
# <Axes: >

# %%
#DROPPING THE COLUMNS HAVING CORRELATION LESS THAN 0.13

for corr,column in zip(data1.corr().iloc[30],data1.columns):
    if abs(corr) < 0.13:
        print(f"{column} has a correlation with class: {corr}")

        data1.drop(columns=column,inplace = True)
# Out:
# Time has a correlation with class: -0.012322570929245588
# V1 has a correlation with class: -0.10134729859508294
# V2 has a correlation with class: 0.0912886503446179
# V5 has a correlation with class: -0.09497429899144802
# V6 has a correlation with class: -0.04364316069996494
# V8 has a correlation with class: 0.019875123914794384
# V9 has a correlation with class: -0.0977326860740807
# V13 has a correlation with class: -0.004569778799461309
# V15 has a correlation with class: -0.004223402267856675
# V18 has a correlation with class: -0.11148525388904133
# V19 has a correlation with class: 0.034783013036515056
# V20 has a correlation with class: 0.020090324196974638
# V21 has a correlation with class: 0.04041338061057565
# V22 has a correlation with class: 0.0008053175052983079
# V23 has a correlation with class: -0.0026851557402507824
# V24 has a correlation with class: -0.007220906715952582
# V25 has a correlation with class: 0.0033077055972996613
# ...

# %%
#HEATMAP OF MODIFIED DATAFRAME

plt.figure(figsize=(15,6))
plt.suptitle('Heatmap Of Modified Dataframe')
sns.heatmap(data1.corr(), cbar = True, annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.show()
